# %% [markdown]
# <a href="https://colab.research.google.com/github/HromovAndrey/II_mood_2_laba/blob/main/Laba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Name':[
        'Canada',
        'France',
        'Germany',
        'Italy',
        'Japan',
        'United Kingdom',
        'United States',
    ],
    'Populatioon':[35.465, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
    'GDP':[
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI':[
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
})

# %%
df
# Out:
#              Name  Populatioon       GDP  Surface Area    HDI Continent
# 0          Canada       35.465   1785387       9984670  0.913   America
# 1          France       63.951   2833687        640679  0.888    Europe
# 2         Germany       80.940   3874437        357114  0.916    Europe
# 3           Italy       60.665   2167744        301336  0.873    Europe
# 4           Japan      127.061   4602367        377930  0.891      Asia
# 5  United Kingdom       64.511   2950039        242495  0.907    Europe
# 6   United States      318.523  17348075       9525067  0.915   America

# %%
print(df)
# Out:
#              Name  Populatioon       GDP  Surface Area    HDI Continent
# 0          Canada       35.465   1785387       9984670  0.913   America
# 1          France       63.951   2833687        640679  0.888    Europe
# 2         Germany       80.940   3874437        357114  0.916    Europe
# 3           Italy       60.665   2167744        301336  0.873    Europe
# 4           Japan      127.061   4602367        377930  0.891      Asia
# 5  United Kingdom       64.511   2950039        242495  0.907    Europe
# 6   United States      318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Name', 'Populatioon', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          7 non-null      object
#  1   Populatioon   7 non-null      float64
#  2   GDP           7 non-null      int64
#  3   Surface Area  7 non-null      int64
#  4   HDI           7 non-null      float64
#  5   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 464.0+ bytes

# %%
df.size
# Out:
# 42

# %%
df.shape
# Out:
# (7, 6)

# %%
df.dtypes
# Out:
# Name             object
# Populatioon     float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df['Populatioon']
# Out:
# 0     35.465
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: Populatioon, dtype: float64

# %%
type(df['HDI'])
# Out:
# pandas.core.series.Series

# %%
df[['Name', 'Populatioon', 'GDP']]
# Out:
#              Name  Populatioon       GDP
# 0          Canada       35.465   1785387
# 1          France       63.951   2833687
# 2         Germany       80.940   3874437
# 3           Italy       60.665   2167744
# 4           Japan      127.061   4602367
# 5  United Kingdom       64.511   2950039
# 6   United States      318.523  17348075

# %%
df.iloc[:, 0:2] #
# Out:
#              Name  Populatioon
# 0          Canada       35.465
# 1          France       63.951
# 2         Germany       80.940
# 3           Italy       60.665
# 4           Japan      127.061
# 5  United Kingdom       64.511
# 6   United States      318.523

# %%
df.iloc[1, 0:2]  #Для індексування DataFrame як матрицю numpy  можна використовувати метод iloc
# Out:
# Name           France
# Populatioon    63.951
# Name: 1, dtype: object

# %%
df.loc[:,['Name', 'Populatioon']] # якщо потрібно вказувати не індекси а назви стовпців то використовуємо метод loc
# Out:
#              Name  Populatioon
# 0          Canada       35.465
# 1          France       63.951
# 2         Germany       80.940
# 3           Italy       60.665
# 4           Japan      127.061
# 5  United Kingdom       64.511
# 6   United States      318.523

# %%
df.loc[1:5, ['Name', 'Populatioon']]
# Out:
#              Name  Populatioon
# 1          France       63.951
# 2         Germany       80.940
# 3           Italy       60.665
# 4           Japan      127.061
# 5  United Kingdom       64.511

# %%
df
# Out:
#              Name  Populatioon       GDP  Surface Area    HDI Continent
# 0          Canada       35.465   1785387       9984670  0.913   America
# 1          France       63.951   2833687        640679  0.888    Europe
# 2         Germany       80.940   3874437        357114  0.916    Europe
# 3           Italy       60.665   2167744        301336  0.873    Europe
# 4           Japan      127.061   4602367        377930  0.891      Asia
# 5  United Kingdom       64.511   2950039        242495  0.907    Europe
# 6   United States      318.523  17348075       9525067  0.915   America

# %%
df['Populatioon'] > 70
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Populatioon, dtype: bool

# %%
df[df['Populatioon'] > 70]
# Out:
#             Name  Populatioon       GDP  Surface Area    HDI Continent
# 2        Germany       80.940   3874437        357114  0.916    Europe
# 4          Japan      127.061   4602367        377930  0.891      Asia
# 6  United States      318.523  17348075       9525067  0.915   America

# %%
df.loc[df['Populatioon'] > 70, ['Name']] #булева маска дозволя вибрати потрібні рядки враховуючи всі ствпчики якщо потрібно вибрати лише деякі стовпці то
#використовується метод  .loc
# Out:
#             Name
# 2        Germany
# 4          Japan
# 6  United States

# %%
df.loc[df['Populatioon'] > 70, ['Name', 'Populatioon', 'GDP']]
# Out:
#             Name  Populatioon       GDP
# 2        Germany       80.940   3874437
# 4          Japan      127.061   4602367
# 6  United States      318.523  17348075

# %%
new_df = df.drop(columns=['Populatioon']) #видалення

# %%
df.drop(columns=['Populatioon']) # якщо ми хочемо зберегти видалития стовпчик
# Out:
#              Name       GDP  Surface Area    HDI Continent
# 0          Canada   1785387       9984670  0.913   America
# 1          France   2833687        640679  0.888    Europe
# 2         Germany   3874437        357114  0.916    Europe
# 3           Italy   2167744        301336  0.873    Europe
# 4           Japan   4602367        377930  0.891      Asia
# 5  United Kingdom   2950039        242495  0.907    Europe
# 6   United States  17348075       9525067  0.915   America

# %%
df
# Out:
#              Name  Populatioon       GDP  Surface Area    HDI Continent
# 0          Canada       35.465   1785387       9984670  0.913   America
# 1          France       63.951   2833687        640679  0.888    Europe
# 2         Germany       80.940   3874437        357114  0.916    Europe
# 3           Italy       60.665   2167744        301336  0.873    Europe
# 4           Japan      127.061   4602367        377930  0.891      Asia
# 5  United Kingdom       64.511   2950039        242495  0.907    Europe
# 6   United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(['Populatioon', 'HDI'], axis=1)
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df
# Out:
#              Name  Populatioon       GDP  Surface Area    HDI Continent
# 0          Canada       35.465   1785387       9984670  0.913   America
# 1          France       63.951   2833687        640679  0.888    Europe
# 2         Germany       80.940   3874437        357114  0.916    Europe
# 3           Italy       60.665   2167744        301336  0.873    Europe
# 4           Japan      127.061   4602367        377930  0.891      Asia
# 5  United Kingdom       64.511   2950039        242495  0.907    Europe
# 6   United States      318.523  17348075       9525067  0.915   America

# %%
df[['Populatioon', 'GDP']]
# Out:
#    Populatioon       GDP
# 0       35.465   1785387
# 1       63.951   2833687
# 2       80.940   3874437
# 3       60.665   2167744
# 4      127.061   4602367
# 5       64.511   2950039
# 6      318.523  17348075

# %%
df[['Populatioon', 'GDP']]
